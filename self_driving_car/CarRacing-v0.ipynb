# %%
import gym
import torch
from torch import nn
import numpy as np
from matplotlib import pyplot as plt

# %%
env = gym.make('CarRacing-v0')

# %%
env.action_space.sample()
# Out:
# array([-0.7367892 ,  0.91142976,  0.580401  ], dtype=float32)

# %%
dir(env.action_space)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'contains',
#  'dtype',
#  'from_jsonable',
#  'high',
#  'low',
#  'np_random',
#  'sample',
#  'seed',
#  'shape',
#  'to_jsonable']

# %%
env.action_space.low
# Out:
# array([-1.,  0.,  0.], dtype=float32)
